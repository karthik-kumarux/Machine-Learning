# %%
#RNN classification

import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import RadiusNeighborsClassifier
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score,recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt

data = load_iris()
df = pd.DataFrame(data.data,columns=data.feature_names)
df['target'] = data.target
df = df[df['target'].isin([0,1])]
X = df.drop('target',axis=1)
y = df['target']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

radius_classifier = RadiusNeighborsClassifier(radius=0.4, outlier_label='most_frequent')
radius_classifier.fit(X_train,y_train)

y_pred = radius_classifier.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)

print(f"accuracy of Radius Classifier:{accuracy*100:.2f}%")

cm = confusion_matrix(y_test,y_pred)

TP = cm[1,1]
TN = cm[0,0]
FP = cm[0,1]
FN = cm[1,0]

Recall = recall_score(y_test,y_pred)
TPR = TP/(TP+FN)
TNR = TN/(TN+FP)
FPR = FP/(TN+FP)
FNR = FN/(TP+FN)

precision = precision_score(y_test,y_pred)

F1 = f1_score(y_test,y_pred)

print(f"True Positive rate(TPR):{TPR:.2f}")
print(f"True Negative rate(TNR):{TNR:.2f}")
print(f"False Positive rate(FPR):{FPR:.2f}")
print(f"False Negative rate(FNR):{FNR:.2f}")
print(f"True positive rate(tpr):{TPR:.2f}")
print(f"F1_score:{F1:.2f}")
print(f"Recall_score:{Recall:.2f}")

plt.figure(figsize=(6,5))
sns.heatmap(cm,annot=True,fmt='d',cmap='Blues',xticklabels=[0,1],yticklabels=[0,1])
plt.xlabel('Pedicted')
plt.ylabel('Actual')
plt.title("confusion matrix(Two classes 0 and 1 for RNN:")
plt.show()
# Out:
# accuracy of Radius Classifier:86.67%
# True Positive rate(TPR):1.00
# True Negative rate(TNR):0.76
# False Positive rate(FPR):0.24
# False Negative rate(FNR):0.00
# True positive rate(tpr):1.00
# F1_score:0.87
# Recall_score:1.00

# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestCentroid
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris

data = load_iris()
df = pd.DataFrame(data.data,columns=data.feature_names)
df['target'] = data.target
df = df[df['target'].isin([0,1])]
X = df.drop('target',axis=1)
y = df['target']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

centroid_classifier = NearestCentroid()
centroid_classifier.fit(X_train,y_train)

y_pred = centroid_classifier.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)

print(f"accuracy of Nearest Centroid Classifier:{accuracy*100:.2f}%")


cm = confusion_matrix(y_test,y_pred)

TP = cm[1,1]
TN = cm[0,0]
FP = cm[0,1]
FN = cm[1,0]

Recall = recall_score(y_test,y_pred)
TPR = TP/(TP+FN)
TNR = TN/(TN+FP)
FPR = FP/(TN+FP)
FNR = FN/(TP+FN)

precision = precision_score(y_test,y_pred)

F1 = f1_score(y_test,y_pred)

print(f"True Positive rate(TPR):{TPR:.2f}")
print(f"True Negative rate(TNR):{TNR:.2f}")
print(f"False Positive rate(FPR):{FPR:.2f}")
print(f"False Negative rate(FNR):{FNR:.2f}")
print(f"True positive rate(tpr):{TPR:.2f}")
print(f"F1_score:{F1:.2f}")
print(f"Recall_score:{Recall:.2f}")

plt.figure(figsize=(6,5))
sns.heatmap(cm,annot=True,fmt='d',cmap='Blues',xticklabels=[0,1],yticklabels=[0,1])
plt.xlabel('Pedicted')
plt.ylabel('Actual')
plt.title("confusion matrix(Two classes 0 and 1 for CNN:")
plt.show()
# Out:
# accuracy of Nearest Centroid Classifier:100.00%
# True Positive rate(TPR):1.00
# True Negative rate(TNR):1.00
# False Positive rate(FPR):0.00
# False Negative rate(FNR):0.00
# True positive rate(tpr):1.00
# F1_score:1.00
# Recall_score:1.00
